# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
from math import pi
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
os.chdir("C:/Users/user/vis")

# %%
def minmax(x):
    x = np.array(x)
    return list((x - min(x)) / (max(x) - min(x)))

# %%
data = pd.read_csv("shanghai.csv")

# %%
data.isna().any()
# Out:
# world_rank         False
# university_name    False
# national_rank      False
# total_score         True
# alumni             False
# award              False
# hici               False
# ns                  True
# pub                False
# pcp                False
# year               False
# dtype: bool

# %%
data.columns
# Out:
# Index(['world_rank', 'university_name', 'national_rank', 'total_score',
#        'alumni', 'award', 'hici', 'ns', 'pub', 'pcp', 'year'],
#       dtype='object')

# %%
Top10 = data.groupby('year').head(10)

# %%
Top10
# Out:
#      world_rank                              university_name national_rank  \
# 0             1                           Harvard University             1
# 1             2                      University of Cambridge             1
# 2             3                          Stanford University             2
# 3             4           University of California, Berkeley             3
# 4             5  Massachusetts Institute of Technology (MIT)             4
# ...         ...                                          ...           ...
# 4400          6                         Princeton University             5
# 4401          7           California Institute of Technology             6
# 4402          8                          Columbia University             7
# 4403          9                        University of Chicago             8
# 4404         10                         University of Oxford             2
#
#       total_score  alumni  award   hici     ns    pub    pcp  year
# ...

# %%
Tail10 = data.groupby('year').tail(10)

# %% [markdown]
# ### 2012

# %%
Top10_2012 = Top10[Top10['year'] == 2012]
Top10_2012 = Top10_2012.reset_index(drop = True)

# %%
labels = np.array(['alumni', 'award', 'hici', 'ns', 'pub', 'pcp'])

for i in labels:
    Top10_2012[i] = minmax(Top10_2012[i])

# %%
stats = Top10_2012.loc[1,labels].values

# %%
stats = Top10_2012.loc[1,labels].values
angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False) # Set the angle

# %%
# close the plot
stats = np.concatenate((stats,[stats[0]]))  # Closed
angles = np.concatenate((angles,[angles[0]]))  # Closed

# %%
stats
# Out:
# array([0.0, 0.5322580645161291, 0.7827788649706459, 0.5218855218855217,
#        0.45225225225225213, 0.26376811594202904, 0.0], dtype=object)

# %%
fig = plt.figure(figsize=(6,4))
plt.style.use('ggplot')

ax = fig.add_subplot(111, polar=True)   # Set polar axis
ax.plot(angles, stats, 'o-', linewidth=0.1)  # Draw the plot (or the frame on the radar chart)
ax.fill(angles, stats, alpha=0.5)  # Fulfill the area

ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
#ax.set_title([df_new_2017.loc[1,"Name"]])  
#ax.set_rlim(0,250)
ax.grid(True)

# %%
def top_rader_map(i):
    stats = Top10_2012.loc[i,labels].values
    angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False) # Set the angle

    # close the plot
    stats = np.concatenate((stats,[stats[0]]))  # Closed
    angles = np.concatenate((angles,[angles[0]]))  # Closed
    
    fig = plt.figure(figsize=(6,4))
    plt.style.use('ggplot')

    ax = fig.add_subplot(111, polar=True)   # Set polar axis
    ax.plot(angles, stats, 'o-', linewidth=0.1)  # Draw the plot (or the frame on the radar chart)
    ax.fill(angles, stats, alpha=0.5)  # Fulfill the area

    ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
    ax.set_title(Top10_2012.loc[i,"university_name"])  
    #ax.set_rlim(0,250)
    ax.grid(True)

# %%
for i in range(10):
    top_rader_map(i)
    plt.savefig('Top10_radermap_Shanghai_' + str(i+1) + '.png', width=150,height = 150)

# %% [markdown]
# ### 2013

# %%
Top10_2013 = Top10[Top10['year'] == 2013]
Top10_2013 = Top10_2013.reset_index(drop = True)

# %%
for i in labels:
    Top10_2013[i] = minmax(Top10_2013[i])

# %%
stats = Top10_2013.loc[1,labels].values

# %%
def top_rader_map(i):
    stats = Top10_2013.loc[i,labels].values
    angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False) # Set the angle

    # close the plot
    stats = np.concatenate((stats,[stats[0]]))  # Closed
    angles = np.concatenate((angles,[angles[0]]))  # Closed
    
    fig = plt.figure(figsize=(6,4))
    plt.style.use('ggplot')

    ax = fig.add_subplot(111, polar=True)   # Set polar axis
    ax.plot(angles, stats, 'o-', linewidth=0.1)  # Draw the plot (or the frame on the radar chart)
    ax.fill(angles, stats, alpha=0.5)  # Fulfill the area

    ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
    ax.set_title(Top10_2013.loc[i,"university_name"])  
    #ax.set_rlim(0,250)
    ax.grid(True)

# %%
for i in range(10):
    top_rader_map(i)
    plt.savefig('Top10_radermap_Shanghai2013_' + str(i+1) + '.png', width=150,height = 150)

# %% [markdown]
# ### 2014

# %%
Top10_2014 = Top10[Top10['year'] == 2014]
Top10_2014 = Top10_2014.reset_index(drop = True)

# %%
for i in labels:
    Top10_2014[i] = minmax(Top10_2014[i])

# %%
stats = Top10_2014.loc[1,labels].values

# %%
def top_rader_map(i):
    stats = Top10_2014.loc[i,labels].values
    angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False) # Set the angle

    # close the plot
    stats = np.concatenate((stats,[stats[0]]))  # Closed
    angles = np.concatenate((angles,[angles[0]]))  # Closed
    
    fig = plt.figure(figsize=(6,4))
    plt.style.use('ggplot')

    ax = fig.add_subplot(111, polar=True)   # Set polar axis
    ax.plot(angles, stats, 'o-', linewidth=0.1)  # Draw the plot (or the frame on the radar chart)
    ax.fill(angles, stats, alpha=0.5)  # Fulfill the area

    ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
    ax.set_title(Top10_2014.loc[i,"university_name"])  
    #ax.set_rlim(0,250)
    ax.grid(True)

# %%
for i in range(10):
    top_rader_map(i)
    plt.savefig('Top10_radermap_Shanghai2014_' + str(i+1) + '.png', width=150,height = 150)

# %% [markdown]
# ### 2015

# %%
Top10_2015 = Top10[Top10['year'] == 2015]
Top10_2015 = Top10_2015.reset_index(drop = True)

# %%
labels = np.array(['alumni', 'award', 'hici', 'ns', 'pub', 'pcp'])

for i in labels:
    Top10_2015[i] = minmax(Top10_2015[i])

# %%
stats = Top10_2015.loc[1,labels].values

# %%
def top_rader_map(i):
    stats = Top10_2015.loc[i,labels].values
    angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False) # Set the angle

    # close the plot
    stats = np.concatenate((stats,[stats[0]]))  # Closed
    angles = np.concatenate((angles,[angles[0]]))  # Closed
    
    fig = plt.figure(figsize=(6,4))
    plt.style.use('ggplot')

    ax = fig.add_subplot(111, polar=True)   # Set polar axis
    ax.plot(angles, stats, 'o-', linewidth=0.1)  # Draw the plot (or the frame on the radar chart)
    ax.fill(angles, stats, alpha=0.5)  # Fulfill the area

    ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
    ax.set_title(Top10_2015.loc[i,"university_name"])  
    #ax.set_rlim(0,250)
    ax.grid(True)

# %%
for i in range(10):
    top_rader_map(i)
    plt.savefig('Top10_radermap_Shanghai2015_' + str(i+1) + '.png', width=150,height = 150)

# %%
data.columns
# Out:
# Index(['world_rank', 'university_name', 'national_rank', 'total_score',
#        'alumni', 'award', 'hici', 'ns', 'pub', 'pcp', 'year'],
#       dtype='object')

# %%
data['university_name'].unique()
# Out:
# array(['Harvard University', 'University of Cambridge',
#        'Stanford University', 'University of California, Berkeley',
#        'Massachusetts Institute of Technology (MIT)',
#        'California Institute of Technology', 'Columbia University',
#        'Princeton University', 'University of Chicago',
#        'University of Oxford', 'Yale University', 'Cornell University',
#        'University of California, San Diego',
#        'University of California, Los Angeles',
#        'University of Pennsylvania', 'University of Wisconsin - Madison',
#        'University of Washington',
#        'University of California, San Francisco',
#        'The Johns Hopkins University', 'The University of Tokyo',
#        'University of Michigan - Ann Arbor', 'Kyoto University',
#        'The Imperial College of Science, Technology and Medicine',
#        'University of Toronto',
#        'University of Illinois at Urbana-Champaign',
#        'University College London',
# ...

# %% [markdown]
# # Swiss

# %%
swiss = data[data['university_name'] == 'Swiss Federal Institute of Technology Zurich']

# %%
swiss = swiss.reset_index(drop = True)
swiss
# Out:
#    world_rank                               university_name national_rank  \
# 0          27  Swiss Federal Institute of Technology Zurich             1
# 1          27  Swiss Federal Institute of Technology Zurich             1
# 2          27  Swiss Federal Institute of Technology Zurich             1
# 3          24  Swiss Federal Institute of Technology Zurich             1
# 4          23  Swiss Federal Institute of Technology Zurich             1
# 5          23  Swiss Federal Institute of Technology Zurich             1
# 6          23  Swiss Federal Institute of Technology Zurich             1
# 7          23  Swiss Federal Institute of Technology Zurich             1
# 8          20  Swiss Federal Institute of Technology Zurich           1.0
# 9          19  Swiss Federal Institute of Technology Zurich             1
# 10         20  Swiss Federal Institute of Technology Zurich             1
#
#     total_score  alumni  award  hici    ns   pub   pcp  year
# ...

# %%
labels = np.array(['alumni', 'award', 'hici', 'ns', 'pub', 'pcp'])

for i in labels:
    swiss[i] = minmax(swiss[i])

# %%
stats = swiss.loc[5,labels].values
angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False) # Set the angle

# %%
stats
# Out:
# array([0.42990654205607476, 0.40000000000000097, 0.36363636363636265,
#        0.6395348837209301, 0.8786127167630057, 0.2142857142857145],
#       dtype=object)

# %%
fig = plt.figure(figsize=(6,4))
plt.style.use('ggplot')

ax = fig.add_subplot(111, polar=True)   # Set polar axis
ax.plot(angles, stats, 'o-', linewidth=0.1)  # Draw the plot (or the frame on the radar chart)
ax.fill(angles, stats, alpha=0.5)  # Fulfill the area

ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
#ax.set_title([df_new_2017.loc[1,"Name"]])  
#ax.set_rlim(0,250)
ax.grid(True)

# %%
def top_rader_map(i):
    stats = swiss.loc[i,labels].values
    angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False) # Set the angle

    # close the plot
    stats = np.concatenate((stats,[stats[0]]))  # Closed
    angles = np.concatenate((angles,[angles[0]]))  # Closed
    
    fig = plt.figure(figsize=(6,4))
    plt.style.use('ggplot')

    ax = fig.add_subplot(111, polar=True)   # Set polar axis
    ax.plot(angles, stats, 'o-', linewidth=0.1)  # Draw the plot (or the frame on the radar chart)
    ax.fill(angles, stats, alpha=0.5)  # Fulfill the area

    ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
    ax.set_title(swiss.loc[i,"university_name"])  
    #ax.set_rlim(0,250)
    ax.grid(True)

# %%
for i in range(6):
    top_rader_map(i)
    plt.savefig('swiss_shanghai' + str(i+1) + '.png', width=150,height = 150)

# %% [markdown]
# ## Imperial

# %%
imperial = data[data['university_name'] == "The Imperial College of Science, Technology and Medicine"]

# %%
labels = np.array(['alumni', 'award', 'hici', 'ns', 'pub', 'pcp'])

for i in labels:
    imperial[i] = minmax(swiss[i])
# Out:
# <ipython-input-52-fa4fdbbc6ed1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imperial[i] = minmax(swiss[i])

# %%
imperial = imperial.reset_index(drop=True)

# %%
stats = imperial.loc[1,labels].values
angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False) # Set the angle

# %%
fig = plt.figure(figsize=(6,4))
plt.style.use('ggplot')

ax = fig.add_subplot(111, polar=True)   # Set polar axis
ax.plot(angles, stats, 'o-', linewidth=0.1)  # Draw the plot (or the frame on the radar chart)
ax.fill(angles, stats, alpha=0.5)  # Fulfill the area

ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
#ax.set_title([df_new_2017.loc[1,"Name"]])  
#ax.set_rlim(0,250)
ax.grid(True)

# %%
def top_rader_map(i):
    stats = imperial.loc[i,labels].values
    angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False) # Set the angle

    # close the plot
    stats = np.concatenate((stats,[stats[0]]))  # Closed
    angles = np.concatenate((angles,[angles[0]]))  # Closed
    
    fig = plt.figure(figsize=(6,4))
    plt.style.use('ggplot')

    ax = fig.add_subplot(111, polar=True)   # Set polar axis
    ax.plot(angles, stats, 'o-', linewidth=0.1)  # Draw the plot (or the frame on the radar chart)
    ax.fill(angles, stats, alpha=0.5)  # Fulfill the area

    ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
    ax.set_title(imperial.loc[i,"university_name"])  
    #ax.set_rlim(0,250)
    ax.grid(True)

# %%
for i in range(6):
    top_rader_map(i)
    plt.savefig('imperial_shanghai' + str(i+1) + '.png', width=150,height = 150)
