# %%
import os
import pandas as pd
import numpy as np

os.chdir("C:/Users/user/vis")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
data = pd.read_excel("times_final_withCountry.xlsx")
data
# Out:
#       world_rank                     university_name    country  teaching  \
# 0              1  California Institute of Technology        USA      95.7
# 1              2                  Harvard University        USA      95.8
# 2              2                 Stanford University        USA      94.8
# 3              4                University of Oxford         UK      89.5
# 4              5                Princeton University        USA      91.5
# ...          ...                                 ...        ...       ...
# 1598         375                   Waseda University      Japan      25.5
# 1599         375         Washington State University        USA      28.5
# 1600         375           Western Sydney University  Australia      17.8
# 1601         375                    Wuhan University      China      34.1
# 1602         375      Wuhan University of Technology      China      16.2
#
#       international  research  citations  income  total_score  num_students  \
# ...

# %%
data['year'].unique()
# Out:
# array([2012, 2013, 2014, 2015], dtype=int64)

# %%
data.isna().any()
# Out:
# world_rank                False
# university_name           False
# country                   False
# teaching                  False
# international             False
# research                  False
# citations                 False
# income                    False
# total_score               False
# num_students              False
# student_staff_ratio       False
# international_students    False
# female_male_ratio         False
# year                      False
# dtype: bool

# %%
import plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go

# word cloud library
from wordcloud import WordCloud

# matplotlib library
import matplotlib.pyplot as plt

x2011 = data.country[data.year == 2012]

plt.subplots(figsize = (8,8))

wordcloud = WordCloud (
                    background_color = 'Black',
                    width = 512,
                    height = 384
                        ).generate(' '.join(x2011))
plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('Plotly-World_Cloud_times2012(AP).png')
plt.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
x2013 = data.country[data.year == 2013]

plt.subplots(figsize = (8,8))

wordcloud = WordCloud (
                    background_color = 'Black',
                    width = 512,
                    height = 384
                        ).generate(' '.join(x2013))
plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('Plotly-World_Cloudtimes2013(AP).png')
plt.show()

# %%
x2014 = data.country[data.year == 2014]

plt.subplots(figsize = (8,8))

wordcloud = WordCloud (
                    background_color = 'Black',
                    width = 512,
                    height = 384
                        ).generate(' '.join(x2014))
plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('Plotly-World_Cloudtimes2014(AP).png')
plt.show()

# %%
x2015 = data.country[data.year == 2015]

plt.subplots(figsize = (8,8))

wordcloud = WordCloud (
                    background_color = 'Black',
                    width = 512,
                    height = 384
                        ).generate(' '.join(x2015))
plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('Plotly-World_Cloudtimes2015(AP).png')
plt.show()

# %%
data['country'].unique()
# Out:
# array(['USA', 'UK', 'Switzerland', 'Canada', 'Japan', 'Sweden',
#        'HongKong', 'Australia', 'Singapore', 'Germany', 'China',
#        'SouthKorea', 'France', 'Belgium', 'Netherlands', 'Finland',
#        'SouthAfrica', 'Ireland', 'Israel', 'Denmark', 'Austria', 'Taiwan',
#        'NewZealand', 'Brazil', 'Norway', 'Spain', 'Turkey', 'Italy',
#        'Russia', 'Greece', 'Iceland', 'Egypt', 'CzechRepublic', 'India',
#        'Poland', 'Iran', 'Portugal', 'Thailand', 'Chile', 'Estonia',
#        'SaudiArabia', 'Mexico', 'Colombia', 'Macau', 'Morocco'],
#       dtype=object)
